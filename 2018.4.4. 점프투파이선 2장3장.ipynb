# %% [markdown]
# # 점프투 파이선 2장 이어서
# ## 3절 리스트

# %%
odd = [1, 3, 5, 7, 9]

# %%
 c = ['Life', 'is', 'too', 'short']

# %%
 d = [1, 2, 'Life', 'is']

# %%
 e = [1, 2, ['Life', 'is']]

# %% [markdown]
# ## 리스트의 인덱싱

# %%
 a = [1, 2, 3]

# %%
 a[-1]
# Out:
# 3

# %%
a[0]
# Out:
# 1

# %%
a[0
# Out:
# 1

# %% [markdown]
# ## 리스트의 슬라이싱

# %%
a=(1,2,3,4,5,)
a(1,2,3,4,5,)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-134450c99b1e> in <module>()
#       1 a=(1,2,3,4,5,)
# ----> 2 a(1,2,3,4,5,)
#
# TypeError: 'tuple' object is not callable

# %%
 a = [1, 2, 3, 4, 5]
>>> a[0:2]
# Out:
# [1, 2]

# %% [markdown]
# ### 리스트의 연산자

# %%
print(a,b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-c704b7a6b29d> in <module>()
# ----> 1 print(a,b)
#
# NameError: name 'b' is not defined

# %%
 a = [1, 2, 3]
>>> b = [4, 5, 6]
>>> a + b
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# ### 리스트의 수정,변경,삭제

# %%
 a = [1, 2, 3]
>>> a[2] = 4

# %%
 a = [1, 2, 3]
>>> a[2] = 4
>>> a
# Out:
# [1, 2, 4]

# %%
a[1:2]
# Out:
# [2]

# %%
a[1:2] = ['a', 'b', 'c']
>>> a
# Out:
# [1, 'a', 'b', 'c', 4]

# %% [markdown]
# ### 리스트 함수

# %%
 a = [1, 2, 3]
>>> a.append(4)

# %%
a = [1, 2, 3]
>>> a.append(4)
>>> a
# Out:
# [1, 2, 3, 4]

# %%
a.append([5,6])
>>> a
# Out:
# [1, 2, 3, 4, [5, 6]]

# %%
a = [1, 4, 3, 2]
>>> a.sort()
>>> a
# Out:
# [1, 2, 3, 4]

# %%
a = ['a', 'c', 'b']
>>> a.sort()
>>> a
# Out:
# ['a', 'b', 'c']

# %%
a = [1,2,3,1]
>>> a.count(1)
# Out:
# 2

# %%
 a = [1,2,3]
>>> a.extend([4,5])
>>> a
# Out:
# [1, 2, 3, 4, 5]

# %%
b = [6, 7]
>>> a.extend(b)
>>> a
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
a = [1, 2, 3, 'a', 'b', 'c']
>>> a.remove('a')
>>> a
# Out:
# [1, 2, 3, 'b', 'c']

# %%
a = [1, 2, 3, 'a', 'b', 'c']
>>> a.pop(4)
'b'
>>> a
# Out:
# [1, 2, 3, 'a', 'c']

# %%
 a = [1, 2, 3, 'a', 'b', 'c']
>>> del a[4]
>>> a
# Out:
# [1, 2, 3, 'a', 'c']

# %% [markdown]
# ## 튜플

# %%
 t1 = ()
>>> t2 = (1,)
>>> t3 = (1, 2, 3)
>>> t4 = 1, 2, 3
